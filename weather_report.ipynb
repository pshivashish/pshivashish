# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
bangalore=pd.read_csv(r"https://github.com/pshivashish/pshivashish/raw/main/bengaluru.csv")
print(bangalore.head)
# Out:
# <bound method NDFrame.head of                  date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 0      2009-01-01 00:00:00        27        12           0.0     11.6
# 1      2009-01-01 01:00:00        27        12           0.0     11.6
# 2      2009-01-01 02:00:00        27        12           0.0     11.6
# 3      2009-01-01 03:00:00        27        12           0.0     11.6
# 4      2009-01-01 04:00:00        27        12           0.0     11.6
# ...                    ...       ...       ...           ...      ...
# 96427  2020-01-01 19:00:00        26        18           0.0      8.7
# 96428  2020-01-01 20:00:00        26        18           0.0      8.7
# 96429  2020-01-01 21:00:00        26        18           0.0      8.7
# 96430  2020-01-01 22:00:00        26        18           0.0      8.7
# 96431  2020-01-01 23:00:00        26        18           0.0      8.7
#
#        uvIndex  uvIndex.1  moon_illumination  moonrise   moonset  ...  \
# ...
